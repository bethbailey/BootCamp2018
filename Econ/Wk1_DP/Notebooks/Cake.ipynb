# %% [markdown]
# # The Deterministic Cake Eating Problem - Value Function Iteration Solution
# ### by [Jason DeBacker](http://jasondebacker.com), June 2018
# This Jupyter notebook illustrates how to solve the deterministic cake eating problem using value function iteration (VFI).
#
#
# ## The Problem:
#
# $$V(w)=\max_{c} u(c)+\beta V(w'), \forall w\in[0,\bar{w}]$$
#
# or, substituting in the law of motion: $w' = w - c$,
#
# $$V(w)=\max_{0\leq w' \leq w}u(w-w')+\beta V(w'), \forall w$$
#
# The unknowns in this system are functions: The value function, $V(w)$, and the policy function, $c = \phi(w)$ (or, equivalently, $w' = p(w)$).
#
# ## The Solution:
#
# We'll solve this problem with value function iteration (VFI).  With this method, we'll use an iterative procedure to converge to a fixed point in function space, the true value function, $V(w)$.
#
# The computational algorithm for VFI is as follows:
#
# 1. Create a discrete grid of the state variable, $w$
# 2. Make an initial guess at the value function, $V_{0}(w)$
#     * This will be a value for each point in the state space
# 3. Perform the operation:
# $$TV(w) = \max_{w'}u(w-w') + \beta V_{0}(w')$$
# 4. Update the guess at the value function: $V_{1}(w) = TV(w)$
# 5. Repeat this process:
# $$V_{i+1} \ (w) = TV(w) = \max_{w'}u(w-w') + \beta V_{i}(w)$$
# 6. Stop when, $|V_{i+1} \ (w)-V_{i}(w)|<\varepsilon$, where $\varepsilon$ is a small number.

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt

# to print plots inline
# %matplotlib inline

# %% [markdown]
# ## Step 1: Set parameter values
#
# Parameters:
# * $\beta$ = rate of time preference
# * $\sigma$ = coefficient of relative risk aversion (if $\sigma = 1$, $u(c)=log(c)$), parameter describes the curvature of the utility function

# %%
beta = 0.95
sigma = 1.0 ## Cake doesn't grow or shrink over time
## Utility function u(c) = (c^(1-sigma)-1)/(1-sigma)
R = 1

# %% [markdown]
# ## Step 2: Create Grid Space
# We will solve this model over a discrete grid.  So we'll set a grid with a finite number of pionts, each of which represent an amount of cake.
#
# We'll also want to know the flow utility from consuming each amount of cake that is possible given this grid.

# %%
'''
------------------------------------------------------------------------
Create Grid for State Space    
------------------------------------------------------------------------
lb_w      = scalar, lower bound of cake grid
ub_w      = scalar, upper bound of cake grid 
size_w    = integer, number of grid points in cake state space
w_grid    = vector, size_w x 1 vector of cake grid points 
------------------------------------------------------------------------
'''
lb_w = 0.4 
ub_w = 2.0 
size_w = 200  # Number of grid points 
## THIS GRID IS NOT TRIVIAL, will influence error
w_grid = np.linspace(lb_w, ub_w, size_w)

'''
------------------------------------------------------------------------
Create grid of current utility values    
------------------------------------------------------------------------
C        = matrix, current consumption (c=w-w')
U        = matrix, current period utility value for all possible
           choices of w and w' (rows are w, columns w')
------------------------------------------------------------------------
'''
C = np.zeros((size_w, size_w)) 
for i in range(size_w): # loop over w
    for j in range(size_w): # loop over w'
        C[i, j] = w_grid[i] - w_grid[j] / R # note that if w'>w, consumption negative
# replace 0 and negative consumption with a tiny value 
# This is a way to impose non-negativity on cons
C[C<=0] = 1e-15
if sigma == 1:
    U = np.log(C)
else:
    U = (C ** (1 - sigma)) / (1 - sigma)
U[C<0] = -9999999

# %% [markdown]
# ## Step 3: Value Function Iteration

# %%
'''
------------------------------------------------------------------------
Value Function Iteration    
------------------------------------------------------------------------
VFtol     = scalar, tolerance required for value function to converge
VFdist    = scalar, distance between last two value functions
VFmaxiter = integer, maximum number of iterations for value function
V         = vector, the value functions at each iteration
Vmat      = matrix, the value for each possible combination of w and w'
Vstore    = matrix, stores V at each iteration 
VFiter    = integer, current iteration number
TV        = vector, the value function after applying the Bellman operator
PF        = vector, indicies of choices of w' for all w 
VF        = vector, the "true" value function
------------------------------------------------------------------------
'''
VFtol = 1e-8 
VFdist = 7.0 
VFmaxiter = 3000 
V = np.zeros(size_w) # initial guess at value function
Vmat = np.zeros((size_w, size_w)) # initialize Vmat matrix
Vstore = np.zeros((size_w, VFmaxiter)) #initialize Vstore array
VFiter = 1 
while VFdist > VFtol and VFiter < VFmaxiter:  
    for i in range(size_w): # loop over w
        for j in range(size_w): # loop over w'
            Vmat[i, j] = U[i, j] + beta * V[j] 
      
    Vstore[:, VFiter] = V.reshape(size_w,) # store value function at each iteration for graphing later
    TV = Vmat.max(1) # apply max operator to Vmat (to get V(w))
    PF = np.argmax(Vmat, axis=1)
    VFdist = (np.absolute(V - TV)).max()  # check distance
    print("Iteration", VFiter, "distance =", VFdist)
    V = TV
    VFiter += 1 
    


if VFiter < VFmaxiter:
    print('Value function converged after this many iterations:', VFiter)
else:
    print('Value function did not converge')            


VF = V # solution to the functional equation
# Out:
# Iteration 1 distance = 34.5387763949
# Iteration 2 distance = 29.2689717516
# Iteration 3 distance = 25.5461036976
# Iteration 4 distance = 22.4813990412
# Iteration 5 distance = 19.8685533778
# Iteration 6 distance = 17.2656877965
# Iteration 7 distance = 14.930791533
# Iteration 8 distance = 12.8910419648
# Iteration 9 distance = 11.0952516262
# Iteration 10 distance = 9.50597844708
# Iteration 11 distance = 7.97963894395
# Iteration 12 distance = 6.55599337313
# Iteration 13 distance = 5.27931757923
# Iteration 14 distance = 4.1416933309
# Iteration 15 distance = 3.04535049033
# Iteration 16 distance = 2.89308296582
# Iteration 17 distance = 2.717150551
# Iteration 18 distance = 2.55306438792
# Iteration 19 distance = 2.39993482495
# Iteration 20 distance = 2.23510290356
# Iteration 21 distance = 2.12334775838
# Iteration 22 distance = 2.00856355928
# Iteration 23 distance = 1.89853027105
# Iteration 24 distance = 1.787547307
# Iteration 25 distance = 1.69603308261
# Iteration 26 distance = 1.60692729655
# Iteration 27 distance = 1.51952029306
# Iteration 28 distance = 1.43811353824
# Iteration 29 distance = 1.36015424626
# Iteration 30 distance = 1.29114222003
# Iteration 31 distance = 1.2261215713
# Iteration 32 distance = 1.16196004367
# Iteration 33 distance = 1.09917786954
# Iteration 34 distance = 1.04393033759
# Iteration 35 distance = 0.991269764249
# Iteration 36 distance = 0.940191173081
# Iteration 37 distance = 0.893181614427
# Iteration 38 distance = 0.84618440442
# Iteration 39 distance = 0.801937778816
# Iteration 40 distance = 0.761639322866
# Iteration 41 distance = 0.723233288785
# Iteration 42 distance = 0.687018040336
# Iteration 43 distance = 0.652491987376
# Iteration 44 distance = 0.616070274359
# Iteration 45 distance = 0.585266760641
# Iteration 46 distance = 0.556003422609
# Iteration 47 distance = 0.528203251479
# Iteration 48 distance = 0.501793088905
# Iteration 49 distance = 0.47670343446
# Iteration 50 distance = 0.452868262737
# Iteration 51 distance = 0.4302248496
# Iteration 52 distance = 0.40871360712
# Iteration 53 distance = 0.388277926764
# Iteration 54 distance = 0.368864030426
# Iteration 55 distance = 0.350420828904
# Iteration 56 distance = 0.332899787459
# Iteration 57 distance = 0.316254798086
# Iteration 58 distance = 0.300442058182
# Iteration 59 distance = 0.285419955273
# Iteration 60 distance = 0.271148957509
# Iteration 61 distance = 0.257591509634
# Iteration 62 distance = 0.244711934152
# Iteration 63 distance = 0.232476337444
# Iteration 64 distance = 0.220852520572
# Iteration 65 distance = 0.209809894544
# Iteration 66 distance = 0.199319399816
# Iteration 67 distance = 0.189353429826
# Iteration 68 distance = 0.179199674252
# Iteration 69 distance = 0.17023969054
# Iteration 70 distance = 0.161192845526
# Iteration 71 distance = 0.15313320325
# Iteration 72 distance = 0.145476543087
# Iteration 73 distance = 0.138202715933
# Iteration 74 distance = 0.131292580136
# Iteration 75 distance = 0.12472795113
# Iteration 76 distance = 0.118491553573
# Iteration 77 distance = 0.112566975894
# Iteration 78 distance = 0.1069386271
# Iteration 79 distance = 0.101591695745
# Iteration 80 distance = 0.0965121109575
# Iteration 81 distance = 0.0916865054096
# Iteration 82 distance = 0.0871021801391
# Iteration 83 distance = 0.0827470711322
# Iteration 84 distance = 0.0786097175756
# Iteration 85 distance = 0.0746792316968
# Iteration 86 distance = 0.0709452701119
# Iteration 87 distance = 0.0673980066064
# Iteration 88 distance = 0.064028106276
# Iteration 89 distance = 0.0608267009622
# Iteration 90 distance = 0.0577853659141
# Iteration 91 distance = 0.0548960976184
# Iteration 92 distance = 0.0521512927375
# Iteration 93 distance = 0.0495437281006
# Iteration 94 distance = 0.0470665416956
# Iteration 95 distance = 0.0447132146108
# Iteration 96 distance = 0.0424775538803
# Iteration 97 distance = 0.0403536761863
# Iteration 98 distance = 0.038335992377
# Iteration 99 distance = 0.0364191927581
# Iteration 100 distance = 0.0345982331202
# Iteration 101 distance = 0.0328683214642
# Iteration 102 distance = 0.031224905391
# Iteration 103 distance = 0.0296636601215
# Iteration 104 distance = 0.0281804771154
# Iteration 105 distance = 0.0267714532596
# Iteration 106 distance = 0.0254328805967
# Iteration 107 distance = 0.0239767405476
# Iteration 108 distance = 0.0227779035202
# Iteration 109 distance = 0.0216390083442
# Iteration 110 distance = 0.020557057927
# Iteration 111 distance = 0.0195292050307
# Iteration 112 distance = 0.0185527447791
# Iteration 113 distance = 0.0176251075402
# Iteration 114 distance = 0.0167438521632
# Iteration 115 distance = 0.015906659555
# Iteration 116 distance = 0.0151113265773
# Iteration 117 distance = 0.0143557602484
# Iteration 118 distance = 0.013637972236
# Iteration 119 distance = 0.0129560736242
# Iteration 120 distance = 0.012308269943
# Iteration 121 distance = 0.0116928564458
# Iteration 122 distance = 0.0111082136235
# Iteration 123 distance = 0.0105528029424
# Iteration 124 distance = 0.0100251627953
# Iteration 125 distance = 0.0095239046555
# Iteration 126 distance = 0.00904770942272
# Iteration 127 distance = 0.00859532395158
# Iteration 128 distance = 0.00816555775401
# Iteration 129 distance = 0.00775727986631
# Iteration 130 distance = 0.007369415873
# Iteration 131 distance = 0.00700094507934
# Iteration 132 distance = 0.00665089782538
# Iteration 133 distance = 0.00631835293412
# Iteration 134 distance = 0.00600243528741
# Iteration 135 distance = 0.00570231352305
# Iteration 136 distance = 0.0054171978469
# Iteration 137 distance = 0.00514633795456
# Iteration 138 distance = 0.00488902105678
# Iteration 139 distance = 0.00464457000395
# Iteration 140 distance = 0.00441234150375
# Iteration 141 distance = 0.00419172442857
# Iteration 142 distance = 0.00398213820714
# Iteration 143 distance = 0.00378303129679
# Iteration 144 distance = 0.00359387973192
# Iteration 145 distance = 0.00341418574533
# Iteration 146 distance = 0.00324347645807
# Iteration 147 distance = 0.00308130263517
# Iteration 148 distance = 0.00292723750341
# Iteration 149 distance = 0.00278087562825
# Iteration 150 distance = 0.00264183184683
# Iteration 151 distance = 0.0025097402545
# Iteration 152 distance = 0.00238425324177
# Iteration 153 distance = 0.00226504057969
# Iteration 154 distance = 0.00215178855071
# Iteration 155 distance = 0.00204419912316
# Iteration 156 distance = 0.00194198916701
# Iteration 157 distance = 0.00184488970866
# Iteration 158 distance = 0.00175264522323
# Iteration 159 distance = 0.00166501296208
# Iteration 160 distance = 0.00158176231398
# Iteration 161 distance = 0.00150267419828
# Iteration 162 distance = 0.00142754048836
# Iteration 163 distance = 0.00135616346395
# Iteration 164 distance = 0.00128835529075
# Iteration 165 distance = 0.00122393752622
# Iteration 166 distance = 0.00116274064992
# Iteration 167 distance = 0.00110460361742
# Iteration 168 distance = 0.00104937343656
# Iteration 169 distance = 0.00099690476469
# Iteration 170 distance = 0.000947059526453
# Iteration 171 distance = 0.000899706550143
# Iteration 172 distance = 0.000854721222638
# Iteration 173 distance = 0.000811985161505
# Iteration 174 distance = 0.00077138590342
# Iteration 175 distance = 0.000732816608249
# Iteration 176 distance = 0.000696175777847
# Iteration 177 distance = 0.00066136698895
# Iteration 178 distance = 0.000628298639512
# Iteration 179 distance = 0.000596883707544
# Iteration 180 distance = 0.000567039522167
# Iteration 181 distance = 0.000538687546054
# Iteration 182 distance = 0.000511753168752
# Iteration 183 distance = 0.000486165510324
# Iteration 184 distance = 0.000461857234811
# Iteration 185 distance = 0.000438764373058
# Iteration 186 distance = 0.000416826154407
# Iteration 187 distance = 0.000395984846691
# Iteration 188 distance = 0.000376185604352
# Iteration 189 distance = 0.000357376324146
# Iteration 190 distance = 0.000339507507931
# Iteration 191 distance = 0.000322532132543
# Iteration 192 distance = 0.000306405525919
# Iteration 193 distance = 0.000291085249629
# Iteration 194 distance = 0.000276530987151
# Iteration 195 distance = 0.000262704437787
# Iteration 196 distance = 0.000249569215896
# Iteration 197 distance = 0.000237090755107
# Iteration 198 distance = 0.000225236217361
# Iteration 199 distance = 0.000213974406492
# Iteration 200 distance = 0.000203275686161
# Iteration 201 distance = 0.000193111901851
# Iteration 202 distance = 0.000183456306758
# Iteration 203 distance = 0.000174283491418
# Iteration 204 distance = 0.000165569316863
# Iteration 205 distance = 0.000157290851021
# Iteration 206 distance = 0.000149426308468
# Iteration 207 distance = 0.00014195499304
# Iteration 208 distance = 0.000134857243395
# Iteration 209 distance = 0.000128114381226
# Iteration 210 distance = 0.000121708662164
# Iteration 211 distance = 0.00011562322905
# Iteration 212 distance = 0.000109842067602
# Iteration 213 distance = 0.000104349964218
# Iteration 214 distance = 9.91324660191e-05
# Iteration 215 distance = 9.41758427189e-05
# Iteration 216 distance = 8.94670505858e-05
# Iteration 217 distance = 8.49936980529e-05
# Iteration 218 distance = 8.07440131609e-05
# Iteration 219 distance = 7.67068125072e-05
# Iteration 220 distance = 7.28714718861e-05
# Iteration 221 distance = 6.92278982939e-05
# Iteration 222 distance = 6.57665033827e-05
# Iteration 223 distance = 6.24781782079e-05
# Iteration 224 distance = 5.93542692968e-05
# Iteration 225 distance = 5.63865558405e-05
# Iteration 226 distance = 5.35672280506e-05
# Iteration 227 distance = 5.08888666388e-05
# Iteration 228 distance = 4.83444233055e-05
# Iteration 229 distance = 4.59272021516e-05
# Iteration 230 distance = 4.36308420433e-05
# Iteration 231 distance = 4.14492998999e-05
# Iteration 232 distance = 3.93768349056e-05
# Iteration 233 distance = 3.74079931618e-05
# Iteration 234 distance = 3.55375935044e-05
# Iteration 235 distance = 3.37607138476e-05
# Iteration 236 distance = 3.20726781524e-05
# Iteration 237 distance = 3.04690442192e-05
# Iteration 238 distance = 2.89455920068e-05
# Iteration 239 distance = 2.74983124058e-05
# Iteration 240 distance = 2.61233967933e-05
# Iteration 241 distance = 2.48172269579e-05
# Iteration 242 distance = 2.35763656065e-05
# Iteration 243 distance = 2.23975473261e-05
# Iteration 244 distance = 2.12776699584e-05
# Iteration 245 distance = 2.02137864562e-05
# Iteration 246 distance = 1.92030971391e-05
# Iteration 247 distance = 1.82429422892e-05
# Iteration 248 distance = 1.73307951741e-05
# Iteration 249 distance = 1.64642554239e-05
# Iteration 250 distance = 1.56410426513e-05
# Iteration 251 distance = 1.48589905251e-05
# Iteration 252 distance = 1.4116041001e-05
# Iteration 253 distance = 1.34102389495e-05
# Iteration 254 distance = 1.27397269978e-05
# Iteration 255 distance = 1.21027406408e-05
# Iteration 256 distance = 1.14976036087e-05
# Iteration 257 distance = 1.09227234333e-05
# Iteration 258 distance = 1.03765872694e-05
# Iteration 259 distance = 9.85775791662e-06
# Iteration 260 distance = 9.36487002434e-06
# Iteration 261 distance = 8.89662651105e-06
# Iteration 262 distance = 8.45179516773e-06
# Iteration 263 distance = 8.02920541787e-06
# Iteration 264 distance = 7.62774516261e-06
# Iteration 265 distance = 7.24635791016e-06
# Iteration 266 distance = 6.88404001892e-06
# Iteration 267 distance = 6.53983801158e-06
# Iteration 268 distance = 6.21284611668e-06
# Iteration 269 distance = 5.90220381014e-06
# Iteration 270 distance = 5.60709362674e-06
# Iteration 271 distance = 5.32673894327e-06
# Iteration 272 distance = 5.06040200321e-06
# Iteration 273 distance = 4.80738189879e-06
# Iteration 274 distance = 4.56701280882e-06
# Iteration 275 distance = 4.33866216554e-06
# Iteration 276 distance = 4.12172906294e-06
# Iteration 277 distance = 3.91564262259e-06
# Iteration 278 distance = 3.71986050141e-06
# Iteration 279 distance = 3.53386747065e-06
# Iteration 280 distance = 3.35717409428e-06
# Iteration 281 distance = 3.18931539312e-06
# Iteration 282 distance = 3.02984962275e-06
# Iteration 283 distance = 2.87835715085e-06
# Iteration 284 distance = 2.73443929188e-06
# Iteration 285 distance = 2.59771732658e-06
# Iteration 286 distance = 2.4678314503e-06
# Iteration 287 distance = 2.34443987779e-06
# Iteration 288 distance = 2.227217891e-06
# Iteration 289 distance = 2.11585700072e-06
# Iteration 290 distance = 2.01006415068e-06
# Iteration 291 distance = 1.90956093604e-06
# Iteration 292 distance = 1.81408289279e-06
# Iteration 293 distance = 1.72337871618e-06
# Iteration 294 distance = 1.63720977753e-06
# Iteration 295 distance = 1.55534928581e-06
# Iteration 296 distance = 1.47758181868e-06
# Iteration 297 distance = 1.40370275403e-06
# Iteration 298 distance = 1.33351761633e-06
# Iteration 299 distance = 1.26684170709e-06
# Iteration 300 distance = 1.20349962174e-06
# Iteration 301 distance = 1.14332463852e-06
# Iteration 302 distance = 1.08615840588e-06
# Iteration 303 distance = 1.03185048772e-06
# Iteration 304 distance = 9.80257965466e-07
# Iteration 305 distance = 9.31245068614e-07
# Iteration 306 distance = 8.84682819446e-07
# Iteration 307 distance = 8.40448691974e-07
# Iteration 308 distance = 7.98426256665e-07
# Iteration 309 distance = 7.58504953069e-07
# Iteration 310 distance = 7.20579706126e-07
# Iteration 311 distance = 6.84550713004e-07
# Iteration 312 distance = 6.5032317309e-07
# Iteration 313 distance = 6.17807017989e-07
# Iteration 314 distance = 5.86916669931e-07
# Iteration 315 distance = 5.57570828619e-07
# Iteration 316 distance = 5.29692286477e-07
# Iteration 317 distance = 5.03207672864e-07
# Iteration 318 distance = 4.78047297747e-07
# Iteration 319 distance = 4.54144924333e-07
# Iteration 320 distance = 4.31437683801e-07
# Iteration 321 distance = 4.09865805295e-07
# Iteration 322 distance = 3.89372516452e-07
# Iteration 323 distance = 3.69903887076e-07
# Iteration 324 distance = 3.51408701249e-07
# Iteration 325 distance = 3.33838258371e-07
# Iteration 326 distance = 3.17146344742e-07
# Iteration 327 distance = 3.01289020399e-07
# Iteration 328 distance = 2.86224576485e-07
# Iteration 329 distance = 2.71913336292e-07
# Iteration 330 distance = 2.58317669477e-07
# Iteration 331 distance = 2.45401793109e-07
# Iteration 332 distance = 2.33131700611e-07
# Iteration 333 distance = 2.21475104922e-07
# Iteration 334 distance = 2.10401353229e-07
# Iteration 335 distance = 1.99881284857e-07
# Iteration 336 distance = 1.89887217061e-07
# Iteration 337 distance = 1.8039284555e-07
# Iteration 338 distance = 1.71373216062e-07
# Iteration 339 distance = 1.62804553838e-07
# Iteration 340 distance = 1.54664334673e-07
# Iteration 341 distance = 1.46931114386e-07
# Iteration 342 distance = 1.39584557246e-07
# Iteration 343 distance = 1.32605336489e-07
# Iteration 344 distance = 1.25975077481e-07
# Iteration 345 distance = 1.1967631508e-07
# Iteration 346 distance = 1.13692507853e-07
# Iteration 347 distance = 1.08007881749e-07
# Iteration 348 distance = 1.02607486951e-07
# Iteration 349 distance = 9.74771126039e-08
# Iteration 350 distance = 9.26032583948e-08
# Iteration 351 distance = 8.79731061332e-08
# Iteration 352 distance = 8.35744486949e-08
# Iteration 353 distance = 7.9395732655e-08
# Iteration 354 distance = 7.54259446012e-08
# Iteration 355 distance = 7.1654653766e-08
# Iteration 356 distance = 6.80719267621e-08
# Iteration 357 distance = 6.46683275818e-08
# Iteration 358 distance = 6.14349033867e-08
# Iteration 359 distance = 5.83631560858e-08
# Iteration 360 distance = 5.54450139134e-08
# Iteration 361 distance = 5.26727603756e-08
# Iteration 362 distance = 5.00391337255e-08
# Iteration 363 distance = 4.75371706443e-08
# Iteration 364 distance = 4.51603057172e-08
# Iteration 365 distance = 4.2902300379e-08
# Iteration 366 distance = 4.07571860706e-08
# Iteration 367 distance = 3.87193210827e-08
# Iteration 368 distance = 3.6783362134e-08
# Iteration 369 distance = 3.49441933167e-08
# Iteration 370 distance = 3.31969829404e-08
# Iteration 371 distance = 3.15371266879e-08
# Iteration 372 distance = 2.99602760379e-08
# Iteration 373 distance = 2.84622529989e-08
# Iteration 374 distance = 2.7039149586e-08
# Iteration 375 distance = 2.56871999227e-08
# Iteration 376 distance = 2.44028370844e-08
# Iteration 377 distance = 2.31827073094e-08
# Iteration 378 distance = 2.20235705228e-08
# Iteration 379 distance = 2.09223856018e-08
# Iteration 380 distance = 1.98762677428e-08
# Iteration 381 distance = 1.888246004e-08
# Iteration 382 distance = 1.79383334853e-08
# Iteration 383 distance = 1.70414153899e-08
# Iteration 384 distance = 1.61893467521e-08
# Iteration 385 distance = 1.53798822566e-08
# Iteration 386 distance = 1.46108760646e-08
# Iteration 387 distance = 1.38803386562e-08
# Iteration 388 distance = 1.31863231445e-08
# Iteration 389 distance = 1.252701054e-08
# Iteration 390 distance = 1.19006529076e-08
# Iteration 391 distance = 1.13056159989e-08
# Iteration 392 distance = 1.07403366201e-08
# Iteration 393 distance = 1.02033226312e-08
# Iteration 394 distance = 9.69315294697e-09
# Value function converged after this many iterations: 395

# %% [markdown]
# ## Step 4: Extract decision rules from solution

# %%
'''
------------------------------------------------------------------------
Find consumption and savings policy functions   
------------------------------------------------------------------------
optW  = vector, the optimal choice of w' for each w
optC  = vector, the optimal choice of c for each c
------------------------------------------------------------------------
'''
optW = w_grid[PF] # tomorrow's optimal cake size (savings function) ## p in notes
optC = w_grid - optW # optimal consumption - get consumption through the transition eqn ## phi in notes

# %% [markdown]
# ## Visualize output

# %%
# Plot value function 
plt.figure()
# plt.plot(wvec, VF)
plt.scatter(w_grid[1:], VF[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Value Function')
plt.title('Value Function - deterministic cake eating')
plt.show()

# %%
# Plot value function at several iterations
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid, Vstore[:,0], label='1st iter')
ax.plot(w_grid, Vstore[:,10], label='0th iter')
ax.plot(w_grid, Vstore[:,20], label='20th iter')
ax.plot(w_grid, Vstore[:,30], label='30th iter')
ax.plot(w_grid, Vstore[:,40], label='40th iter')
ax.plot(w_grid, Vstore[:,VFiter-1], 'k', label='Last iter')
# Now add the legend with some customizations.
legend = ax.legend(loc='lower right', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Value Function')
plt.title('Value Function - deterministic cake eating')
plt.show()

# %%
#Plot optimal consumption rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optC[1:], label='Consumption')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Consumption')
plt.title('Policy Function, consumption - deterministic cake eating')
plt.show()

# %%
#Plot cake to leave rule as a function of cake size
plt.figure()
fig, ax = plt.subplots()
ax.plot(w_grid[1:], optW[1:], label='Savings')
ax.plot(w_grid[1:], w_grid[1:], '--', label='45 degree line')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper left', shadow=False)
# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
for label in legend.get_lines():
    label.set_linewidth(1.5)  # the legend line width
plt.xlabel('Size of Cake')
plt.ylabel('Optimal Savings')
plt.title('Policy Function, savings - deterministic cake eating')
plt.show()

# %% [markdown]
# ## Finding approximation errors
#
# It's a little complicated (we need to do the guess and verify method), but we can show that with $\sigma = 1.0$ (i.e., $u(c) = log(c)$), then the policy function is $w' = \beta w$.  Knowing this, we can find the approximation error from our solution method (VFI over a discrete grid).  This errors are found as:

# %%
Wprime_errors = optW - beta * w_grid

# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], Wprime_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI w prime policy function errors')
plt.show()

# %%
C_errors = optC - (1 - beta) * w_grid
# Plot policy function approximation errors
plt.figure()
plt.plot(w_grid[1:], C_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('VFI consumption policy function errors')
plt.show()

# %%
# Compute true value function if u(c)=log(c)
B = 1 / (1 - beta)
A = B * np.log(1 - beta) + B * B * beta * np.log(R * beta)
true_VF = A + B * np.log(w_grid)
VF_errors = VF - true_VF
# Plot value function approximation errors
plt.figure()
plt.plot(w_grid[1:], VF_errors[1:])
plt.xlabel('Size of Cake')
plt.ylabel('Error')
plt.title('Value function errors')
plt.show()

# %%
# Plot true and found value functions
plt.figure()
plt.plot(w_grid[1:], VF[1:], label='Approximated VF')
plt.plot(w_grid[1:], true_VF[1:], label='True VF')
plt.xlabel('Size of Cake')
plt.ylabel('Value')
plt.title('Value functions')
plt.legend(loc='lower right')
plt.show()
## Could use log of linspace for grid to better approximate smaller values
